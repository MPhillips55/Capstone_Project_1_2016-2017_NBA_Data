# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
tbdf = pd.DataFrame.from_csv('../../Cleaned_NBA_Season_Data/box_Score_Team-Stats_csv.csv', index_col=False)

# %%
tbdf.head()
# Out:
#                     DATASET        DATE        TEAMS VENUE  1Q  2Q  3Q  4Q  \
# 0  2016-2017 Regular Season  10/25/2016     New York  Road  18  27  19  24
# 1  2016-2017 Regular Season  10/25/2016    Cleveland  Home  28  20  34  35
# 2  2016-2017 Regular Season  10/25/2016         Utah  Road  26  20  37  21
# 3  2016-2017 Regular Season  10/25/2016     Portland  Home  26  28  23  36
# 4  2016-2017 Regular Season  10/25/2016  San Antonio  Road  31  33  33  32
#
#    OT1  OT2        ...           POSS   PACE   OEFF   DEFF  REST DAYS  \
# 0  NaN  NaN        ...          100.4  100.4   87.7  116.6         3+
# 1  NaN  NaN        ...          100.4  100.4  116.6   87.7         3+
# 2  NaN  NaN        ...           92.5   92.5  112.4  122.1         3+
# 3  NaN  NaN        ...           92.5   92.5  122.1  112.4         3+
# 4  NaN  NaN        ...           98.8   98.8  130.6  101.2         3+
#
#    STARTING LINEUPS1   STARTING LINEUPS2  STARTING LINEUPS3  \
# ...

# %%
tbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 40 columns):
# DATASET              2460 non-null object
# DATE                 2460 non-null object
# TEAMS                2460 non-null object
# VENUE                2460 non-null object
# 1Q                   2460 non-null int64
# 2Q                   2460 non-null int64
# 3Q                   2460 non-null int64
# 4Q                   2460 non-null int64
# OT1                  140 non-null float64
# OT2                  16 non-null float64
# OT3                  2 non-null float64
# OT4                  2 non-null float64
# F                    2460 non-null int64
# MIN                  2460 non-null int64
# FG                   2460 non-null int64
# FGA                  2460 non-null int64
# 3P                   2460 non-null int64
# 3PA                  2460 non-null int64
# FT                   2460 non-null int64
# FTA                  2460 non-null int64
# ...

# %%
tbdf.drop('DATASET', axis=1, inplace=True)

# %%
tbdf['DATE'] = pd.to_datetime(tbdf['DATE'])

# %%
tbdf['OT1'].unique()
# Out:
# array([ nan,   6.,  15.,   8.,  11.,   9.,   3.,  12.,   5.,  17.,  14.,
#         10.,   1.,  13.,  16.,   7.,  21.,  19.,  20.,   4.])

# %%
tbdf.head()
# Out:
#         DATE        TEAMS VENUE  1Q  2Q  3Q  4Q  OT1  OT2  OT3  \
# 0 2016-10-25     New York  Road  18  27  19  24  NaN  NaN  NaN
# 1 2016-10-25    Cleveland  Home  28  20  34  35  NaN  NaN  NaN
# 2 2016-10-25         Utah  Road  26  20  37  21  NaN  NaN  NaN
# 3 2016-10-25     Portland  Home  26  28  23  36  NaN  NaN  NaN
# 4 2016-10-25  San Antonio  Road  31  33  33  32  NaN  NaN  NaN
#
#          ...           POSS   PACE   OEFF   DEFF  REST DAYS  \
# 0        ...          100.4  100.4   87.7  116.6         3+
# 1        ...          100.4  100.4  116.6   87.7         3+
# 2        ...           92.5   92.5  112.4  122.1         3+
# 3        ...           92.5   92.5  122.1  112.4         3+
# 4        ...           98.8   98.8  130.6  101.2         3+
#
#    STARTING LINEUPS1   STARTING LINEUPS2  STARTING LINEUPS3  \
# 0    Carmelo Anthony  Kristaps Porzingis        Joakim Noah
# 1       LeBron James          Kevin Love   Tristan Thompson
# ...

# %%
tbdf.to_csv('team_box_score_cleaned.csv')

# %%
clean_team_box_score_df = pd.DataFrame.from_csv('../../Cleaned_NBA_Season_Data/team_box_score_cleaned.csv')

# %%
clean_team_box_score_df.head()
# Out:
#          DATE        TEAMS VENUE  1Q  2Q  3Q  4Q  OT1  OT2  OT3  \
# 0  2016-10-25     New York  Road  18  27  19  24  NaN  NaN  NaN
# 1  2016-10-25    Cleveland  Home  28  20  34  35  NaN  NaN  NaN
# 2  2016-10-25         Utah  Road  26  20  37  21  NaN  NaN  NaN
# 3  2016-10-25     Portland  Home  26  28  23  36  NaN  NaN  NaN
# 4  2016-10-25  San Antonio  Road  31  33  33  32  NaN  NaN  NaN
#
#          ...           POSS   PACE   OEFF   DEFF  REST DAYS  \
# 0        ...          100.4  100.4   87.7  116.6         3+
# 1        ...          100.4  100.4  116.6   87.7         3+
# 2        ...           92.5   92.5  112.4  122.1         3+
# 3        ...           92.5   92.5  122.1  112.4         3+
# 4        ...           98.8   98.8  130.6  101.2         3+
#
#    STARTING LINEUPS1   STARTING LINEUPS2  STARTING LINEUPS3  \
# 0    Carmelo Anthony  Kristaps Porzingis        Joakim Noah
# 1       LeBron James          Kevin Love   Tristan Thompson
# ...
